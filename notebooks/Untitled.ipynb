# %%
import numpy as np
from scipy.ndimage import imread
from scipy.misc import imresize
import pylab as plt
import glob
import cPickle as pkl

from science_rcn.inference import test_image
from science_rcn.learning import train_image

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-0f56caa7d9d9> in <module>()
#       6 import cPickle as pkl
#       7
# ----> 8 from science_rcn.inference import test_image
#       9 from science_rcn.learning import train_image
#      10
#
# ImportError: No module named science_rcn.inference

# %%
fnames = glob.glob('../data/MNIST/testing/0/*.bmp')
imgs0 = [imread(f) for f in fnames]
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(imgs[i])

# %%
fnames = glob.glob('../data/MNIST/testing/1/*.bmp')
imgs1 = [imread(f) for f in fnames]
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(imgs[i])

# %%
plt.figure(figsize=(15,15))
img_canvas1 = np.zeros((64, 64))
for x,y,i in zip((5,30,7,27),(5, 4, 25, 23),(0, 1,2,3)):
    img_canvas[x:x+28, y:y+28] = np.maximum(imgs0[i], img_canvas[x:x+28, y:y+28])
for x,y,i in zip((5,30,7,27),(5, 4, 25, 23),(0, 1,2,3)):
    img_canvas1[x:x+28, y:y+28] = np.maximum(imgs1[i], img_canvas[x:x+28, y:y+28])    
plt.imshow(img_canvas1, cmap=plt.cm.Greys_r)

# %%
plt.figure(figsize=(15,15))
img_canvas2 = np.zeros((64, 64))
for x,y,i in zip((5,30,7,27),(5, 4, 25, 23),(0, 1,2,3)):
    img_canvas[x:x+28, y:y+28] = np.maximum(imgs0[i], img_canvas[x:x+28, y:y+28])
for x,y,i in zip((5,30,7,27),(5, 4, 25, 23),(0, 1,2,3)):
    img_canvas[x:x+28, y:y+28] -= (imgs1[i]>0)*img_canvas[x:x+28, y:y+28]    
plt.imshow(img_canvas, cmap=plt.cm.Greys_r)

# %%
with open('../data/MNIST/trained_model', 'r') as f:
    model = pkl.load(f)

# %%
# Out:
# list
